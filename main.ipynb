# %% [markdown]
# # Baking with Gemini
#
# To get started, [get an API key](https://makersuite.google.com/app/apikey) and replace the word `TODO` below with your API key:

# %%
API_KEY = 'AIzaSyCIaJchILi-jud5R3H7Ij3C0nHeSfenNMA'

# %% [markdown]
# Once you're done, create a text prompt here:

# %%
prompt = 'Provide a recipe for the baked goods in the image'

# %% [markdown]
# And load an image with PIL:

# %%
import PIL.Image
# img = PIL.Image.open('baked_goods_1.jpg')
# img = PIL.Image.open('baked_goods_2.jpg')
# img = PIL.Image.open('baked_goods_3.jpg')
img = PIL.Image.open('food4.jpg')

img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1000>

# %% [markdown]
# And finally, call Gemini using the Python client library. [See the docs](https://developers.generativeai.google/guide)

# %%
import google.generativeai as genai
from IPython.display import Markdown, clear_output, display

genai.configure(api_key=API_KEY)

model = genai.GenerativeModel(model_name='gemini-pro-vision')
response = model.generate_content([prompt, img], stream=True)

buffer = []
for chunk in response:
    for part in chunk.parts:
        buffer.append(part.text)
    clear_output()
    display(Markdown(''.join(buffer)))
# Out:
#  **Chicken Biryani**
#
# Ingredients:
#
# * 1 cup basmati rice
# * 1 pound boneless, skinless chicken breasts or thighs, cut into 1-inch pieces
# * 1 cup plain yogurt
# * 1 tablespoon lemon juice
# * 1 teaspoon ground cumin
# * 1 teaspoon ground coriander
# * 1 teaspoon ground turmeric
# * 1 teaspoon garam masala
# * 1/2 teaspoon red chili powder
# * 1/4 teaspoon salt
# * 1/4 cup vegetable oil
# * 1 large onion, thinly sliced
# * 2 cloves garlic, minced
# * 2 tablespoons ginger, minced
# * 1 cup chopped tomatoes
# * 1/2 cup chopped cilantro leaves
# * 1/4 cup chopped mint leaves
#
# Instructions:
#
# 1. In a large bowl, combine the rice, chicken, yogurt, lemon juice, cumin, coriander, turmeric, garam masala, chili powder, and salt. Mix well to coat the chicken evenly.
# 2. Heat the oil in a large skillet over medium heat. Add the chicken and cook until browned on all sides. Remove the chicken from the skillet and set aside.
# ...
